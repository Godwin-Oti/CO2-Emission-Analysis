# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# importing libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## CO2 Emission

# %% [markdown]
# About Car_Raw Dataset

# %%
"""
Sure, let me explain each of the terms mentioned:

1. **OBFCM (On-Board Fuel Consumption Meter)**: It refers to a device or system installed in a vehicle that measures and records the amount of fuel consumed by the vehicle during operation. OBFCM systems are commonly used in vehicles to monitor fuel consumption and efficiency.

2. **Data Source**: This term refers to the origin or the place from which the data is obtained. It could be a sensor, a database, a file, or any other means of collecting data.

3. **ID**: ID stands for Identification. In a dataset, it typically represents a unique identifier for each record or entry. It helps to uniquely identify each data point in the dataset.

4. **OBFCM Reporting Period**: This is the time period over which the data from the OBFCM device is reported or recorded. It could be daily, weekly, monthly, etc., depending on how the data is collected and processed.

5. **Registration Year**: This refers to the year in which the vehicle was registered. It provides information about the age or vintage of the vehicle.

6. **Total fuel consumed (lifetime) (l)**: This represents the total amount of fuel consumed by the vehicle over its lifetime, measured in liters.

7. **Total distance travelled (lifetime) (km)**: This indicates the total distance covered by the vehicle over its lifetime, measured in kilometers.

8. **Total distance travelled in charge depleting operation with engine off (lifetime) (km)**: It represents the total distance traveled by the vehicle while operating in a charge depleting mode with the engine turned off, over its lifetime, measured in kilometers.

9. **Total distance travelled in charge depleting operation with engine running (lifetime) (km)**: This is similar to the previous term, but it represents the total distance traveled by the vehicle in charge depleting mode with the engine running.

10. **Total distance travelled in driver-selectable charge increasing operation (lifetime) (km)**: This refers to the total distance covered by the vehicle while operating in a mode where the driver can increase the charge of the battery, over its lifetime, measured in kilometers.

11. **Total fuel consumed in charge depleting operation (lifetime) (l)**: It indicates the total amount of fuel consumed by the vehicle while operating in charge depleting mode over its lifetime, measured in liters.

12. **Total fuel consumed in driver-selectable charge increasing operation (lifetime) (l)**: Similar to the previous term, but it represents the fuel consumed while operating in a mode where the driver can increase the charge of the battery.

13. **Total grid energy into the battery (lifetime) (kWh)**: This refers to the total amount of energy supplied from an external power grid to charge the vehicle's battery over its lifetime, measured in kilowatt-hours.

14. **Used in calculation**: This likely indicates whether the specific data field was used in any calculations or analyses.

These terms are typically found in datasets related to vehicle performance, fuel consumption, and energy usage, particularly in the context of electric and hybrid vehicles.

The purpose of the charge-depleting mode is to maximize the use of electric power stored in the battery, thereby reducing fuel consumption and emissions, especially during city driving or other low-speed, stop-and-go situations where electric propulsion is most efficient.

In a charge-depleting mode, the vehicle primarily operates using the energy stored in its battery pack. During this mode, the vehicle's electric motor(s) are used to propel the vehicle, drawing power from the battery. This mode is called "depleting" because it's aimed at using up the stored energy in the battery until it reaches a certain threshold level, typically referred to as the "minimum state of charge" (SOC).

.In summary, charge-depleting mode in hybrid and plug-in hybrid vehicles prioritizes the use of electric power from the battery to propel the vehicle, leading to improved fuel efficiency and reduced environmental impact compared to traditional internal combustion engine vehicles.

"""
# Out:
# '\nSure, let me explain each of the terms mentioned:\n\n1. **OBFCM (On-Board Fuel Consumption Meter)**: It refers to a device or system installed in a vehicle that measures and records the amount of fuel consumed by the vehicle during operation. OBFCM systems are commonly used in vehicles to monitor fuel consumption and efficiency.\n\n2. **Data Source**: This term refers to the origin or the place from which the data is obtained. It could be a sensor, a database, a file, or any other means of collecting data.\n\n3. **ID**: ID stands for Identification. In a dataset, it typically represents a unique identifier for each record or entry. It helps to uniquely identify each data point in the dataset.\n\n4. **OBFCM Reporting Period**: This is the time period over which the data from the OBFCM device is reported or recorded. It could be daily, weekly, monthly, etc., depending on how the data is collected and processed.\n\n5. **Registration Year**: This refers to the year in which the vehicle was registered. It provides information about the age or vintage of the vehicle.\n\n6. **Total fuel consumed (lifetime) (l)**: This represents the total amount of fuel consumed by the vehicle over its lifetime, measured in liters.\n\n7. **Total distance travelled (lifetime) (km)**: This indicates the total distance covered by the vehicle over its lifetime, measured in kilometers.\n\n8. **Total distance travelled in charge depleting operation with engine off (lifetime) (km)**: It represents the total distance traveled by the vehicle while operating in a charge depleting mode with the engine turned off, over its lifetime, measured in kilometers.\n\n9. **Total distance travelled in charge depleting operation with engine running (lifetime) (km)**: This is similar to the previous term, but it represents the total distance traveled by the vehicle in charge depleting mode with the engine running.\n\n10. **Total distance travelled in driver-selectable charge increasing operation (lifetime) (km)**: This refers to the total distance covered by the vehicle while operating in a mode where the driver can increase the charge of the battery, over its lifetime, measured in kilometers.\n\n11. **Total fuel consumed in charge depleting operation (lifetime) (l)**: It indicates the total amount of fuel consumed by the vehicle while operating in charge depleting mode over its lifetime, measured in liters.\n\n12. **Total fuel consumed in driver-selectable charge increasing operation (lifetime) (l)**: Similar to the previous term, but it represents the fuel consumed while operating in a mode where the driver can increase the charge of the battery.\n\n13. **Total grid energy into the battery (lifetime) (kWh)**: This refers to the total amount of energy supplied from an external power grid to charge the vehicle\'s battery over its lifetime, measured in kilowatt-hours.\n\n14. **Used in calculation**: This likely indicates whether the specific data field was used in any calculations or analyses.\n\nThese terms are typically found in datasets related to vehicle performance, fuel consumption, and energy usage, particularly in the context of electric and hybrid vehicles.\n\nThe purpose of the charge-depleting mode is to maximize the use of electric power stored in the battery, thereby reducing fuel consumption and emissions, especially during city driving or other low-speed, stop-and-go situations where electric propulsion is most efficient.\n\nIn a charge-depleting mode, the vehicle primarily operates using the energy stored in its battery pack. During this mode, the vehicle\'s electric motor(s) are used to propel the vehicle, drawing power from the battery. This mode is called "depleting" because it\'s aimed at using up the stored energy in the battery until it reaches a certain threshold level, typically referred to as the "minimum state of charge" (SOC).\n\n.In summary, charge-depleting mode in hybrid and plug-in hybrid vehicles prioritizes the use of electric power from t ...

# %% [markdown]
# About Car_agg Dataset

# %%
"""

It appears that you have a dataset with several columns related to vehicle manufacturer, fuel type, number of vehicles, fuel consumption, CO2 emissions, and gaps between different measurements. Let's break down the meaning of each column:

1. **Manufacturer**: This column likely contains the name of the vehicle manufacturer or brand.

2. **Fuel Type**: This column indicates the type of fuel used by the vehicles, such as gasoline, diesel, hybrid, electric, etc.

3. **Number of vehicles**: This column represents the count or quantity of vehicles for each manufacturer and fuel type combination.

4. **OBFCM Fuel Consumption (l/100 km)**: This column provides the fuel consumption rate measured by an On-Board Fuel Consumption Meter (OBFCM), typically expressed in liters per 100 kilometers.

5. **WLTP Fuel Consumption (l/100 km)**: This column represents the fuel consumption rate according to the Worldwide Harmonized Light Vehicles Test Procedure (WLTP), also expressed in liters per 100 kilometers.

6. **Absolute Gap Fuel Consumption (l/100 km)**: This column represents the absolute difference or gap between OBFCM and WLTP fuel consumption values, measured in liters per 100 kilometers.

7. **Percentage Gap Fuel Consumption (%)**: This column represents the percentage difference or gap between OBFCM and WLTP fuel consumption values, expressed as a percentage.

8. **OBFCM CO2 Emissions (g/km)**: This column provides the CO2 emissions rate measured by an On-Board Fuel Consumption Meter (OBFCM), typically expressed in grams per kilometer.

9. **WLTP CO2 Emissions (g/km)**: This column represents the CO2 emissions rate according to the Worldwide Harmonized Light Vehicles Test Procedure (WLTP), also expressed in grams per kilometer.

10. **Absolute Gap CO2 Emissions (g/km)**: This column represents the absolute difference or gap between OBFCM and WLTP CO2 emissions values, measured in grams per kilometer.

11. **Percentage Gap CO2 Emissions (%)**: This column represents the percentage difference or gap between OBFCM and WLTP CO2 emissions values, expressed as a percentage.

12. **OBFCM Fuel Consumption Weighted (l/100 km)**: This column represents a weighted average of fuel consumption rates based on specific conditions or scenarios, as measured by an OBFCM.

13. **WLTP Fuel Consumption Weighted (l/100 km)**: This column represents a weighted average of fuel consumption rates based on specific conditions or scenarios, as measured by WLTP.

14. **Absolute Gap Fuel Consumption Weighted (l/100 km)**: This column represents the absolute difference or gap between OBFCM and WLTP weighted fuel consumption values.

15. **Percentage Gap Fuel Consumption Weighted (%)**: This column represents the percentage difference or gap between OBFCM and WLTP weighted fuel consumption values, expressed as a percentage.

16. **OBFCM CO2 Emissions Weighted (g/km)**: This column represents a weighted average of CO2 emissions rates based on specific conditions or scenarios, as measured by an OBFCM.

17. **WLTP CO2 Emissions Weighted (g/km)**: This column represents a weighted average of CO2 emissions rates based on specific conditions or scenarios, as measured by WLTP.

18. **Absolute Gap CO2 Emissions Weighted (g/km)**: This column represents the absolute difference or gap between OBFCM and WLTP weighted CO2 emissions values.

19. **Percentage Gap CO2 Emissions Weighted (%)**: This column represents the percentage difference or gap between OBFCM and WLTP weighted CO2 emissions values, expressed as a percentage.

These columns provide comprehensive information about fuel consumption, CO2 emissions, and their discrepancies as measured by different methods (OBFCM and WLTP) and under different conditions. They can be analyzed to assess the accuracy of measurement methods, evaluate the environmental impact of vehicles, and compare performance across different manufacturers and fuel types.

"""
# Out:
# "\n\nIt appears that you have a dataset with several columns related to vehicle manufacturer, fuel type, number of vehicles, fuel consumption, CO2 emissions, and gaps between different measurements. Let's break down the meaning of each column:\n\n1. **Manufacturer**: This column likely contains the name of the vehicle manufacturer or brand.\n\n2. **Fuel Type**: This column indicates the type of fuel used by the vehicles, such as gasoline, diesel, hybrid, electric, etc.\n\n3. **Number of vehicles**: This column represents the count or quantity of vehicles for each manufacturer and fuel type combination.\n\n4. **OBFCM Fuel Consumption (l/100 km)**: This column provides the fuel consumption rate measured by an On-Board Fuel Consumption Meter (OBFCM), typically expressed in liters per 100 kilometers.\n\n5. **WLTP Fuel Consumption (l/100 km)**: This column represents the fuel consumption rate according to the Worldwide Harmonized Light Vehicles Test Procedure (WLTP), also expressed in liters per 100 kilometers.\n\n6. **Absolute Gap Fuel Consumption (l/100 km)**: This column represents the absolute difference or gap between OBFCM and WLTP fuel consumption values, measured in liters per 100 kilometers.\n\n7. **Percentage Gap Fuel Consumption (%)**: This column represents the percentage difference or gap between OBFCM and WLTP fuel consumption values, expressed as a percentage.\n\n8. **OBFCM CO2 Emissions (g/km)**: This column provides the CO2 emissions rate measured by an On-Board Fuel Consumption Meter (OBFCM), typically expressed in grams per kilometer.\n\n9. **WLTP CO2 Emissions (g/km)**: This column represents the CO2 emissions rate according to the Worldwide Harmonized Light Vehicles Test Procedure (WLTP), also expressed in grams per kilometer.\n\n10. **Absolute Gap CO2 Emissions (g/km)**: This column represents the absolute difference or gap between OBFCM and WLTP CO2 emissions values, measured in grams per kilometer.\n\n11. **Percentage Gap CO2 Emissions (%)**: This column represents the percentage difference or gap between OBFCM and WLTP CO2 emissions values, expressed as a percentage.\n\n12. **OBFCM Fuel Consumption Weighted (l/100 km)**: This column represents a weighted average of fuel consumption rates based on specific conditions or scenarios, as measured by an OBFCM.\n\n13. **WLTP Fuel Consumption Weighted (l/100 km)**: This column represents a weighted average of fuel consumption rates based on specific conditions or scenarios, as measured by WLTP.\n\n14. **Absolute Gap Fuel Consumption Weighted (l/100 km)**: This column represents the absolute difference or gap between OBFCM and WLTP weighted fuel consumption values.\n\n15. **Percentage Gap Fuel Consumption Weighted (%)**: This column represents the percentage difference or gap between OBFCM and WLTP weighted fuel consumption values, expressed as a percentage.\n\n16. **OBFCM CO2 Emissions Weighted (g/km)**: This column represents a weighted average of CO2 emissions rates based on specific conditions or scenarios, as measured by an OBFCM.\n\n17. **WLTP CO2 Emissions Weighted (g/km)**: This column represents a weighted average of CO2 emissions rates based on specific conditions or scenarios, as measured by WLTP.\n\n18. **Absolute Gap CO2 Emissions Weighted (g/km)**: This column represents the absolute difference or gap between OBFCM and WLTP weighted CO2 emissions values.\n\n19. **Percentage Gap CO2 Emissions Weighted (%)**: This column represents the percentage difference or gap between OBFCM and WLTP weighted CO2 emissions values, expressed as a percentage.\n\nThese columns provide comprehensive information about fuel consumption, CO2 emissions, and their discrepancies as measured by different methods (OBFCM and WLTP) and under different conditions. They can be analyzed to assess the accuracy of measurement methods, evaluate the environmental impact of vehicles, and compare performance across different manufacturers and fuel types.\n\n"

# %% [markdown]
# ## Loading Dataset

# %%
# loading the car raw data set 
car=pd.read_csv("2021_Cars_Raw.csv")

# %%
car.tail(100)
# Out:
#        OBFCM data source        ID  OBFCM ReportingPeriod  Registration Year  \
# 916172               OEM  61109523                   2021               2021
# 916173               OEM  46685678                   2021               2021
# 916174               OEM  50065973                   2021               2021
# 916175               OEM  50065974                   2021               2021
# 916176               OEM  50065977                   2021               2021
# ...                  ...       ...                    ...                ...
# 916267               OEM  50066870                   2021               2021
# 916268               OEM  50066874                   2021               2021
# 916269               OEM  56630133                   2021               2021
# 916270               OEM  53288261                   2021               2021
# 916271               OEM  50066882                   2021               2021
#
#         Total fuel consumed (lifetime) (l)  \
# 916172                             1660.43
# 916173                               78.03
# 916174                             2456.67
# 916175                             3070.44
# 916176                              915.64
# ...                                    ...
# 916267                              895.40
# 916268                             1224.94
# 916269                                8.93
# 916270                                4.04
# 916271                               85.67
#
#         Total distance travelled (lifetime) (km)  \
# 916172                                   17483.6
# 916173                                     712.3
# 916174                                   26513.2
# 916175                                   32541.5
# 916176                                    9475.2
# ...                                          ...
# 916267                                    7551.5
# 916268                                   13579.5
# 916269                                      71.4
# 916270                                      12.4
# 916271                                    1039.1
#
#         Total distance travelled in charge depleting operation with engine off (lifetime) (km)  \
# 916172                                                0.0
# 916173                                                0.0
# 916174                                                0.0
# 916175                                                0.0
# 916176                                                0.0
# ...                                                   ...
# 916267                                                0.0
# 916268                                                0.0
# 916269                                                0.0
# 916270                                                0.0
# 916271                                                0.0
#
#         Total distance travelled in charge depleting operation with engine running (lifetime) (km)  \
# 916172                                                0.0
# 916173                                                0.0
# 916174                                                0.0
# 916175                                                0.0
# 916176                                                0.0
# ...                                                   ...
# 916267                                                0.0
# 916268                                                0.0
# 916269                                                0.0
# 916270                                                0.0
# 916271                                                0.0
#
#         Total distance travelled in driver-selectable charge increasing operation (lifetime)  (km)  \
# 916172                                                0.0
# 916173                                                0.0
# 916174                                                0.0
# 916175                                                0.0
# 916176                                                0.0
# ...                                                   ...
# 916267                                                0.0
# 916268                                                0.0
# 916269                                                0.0
# 916270                                                0.0
# 916271                                                0.0
#
#         Total fuel consumed in charge depleting operation (lifetime) (l)  \
# 916172                                                0.0
# 916173                                                0.0
# 916174                                                0.0
# 916175                                                0.0
# 916176                                                0.0
# ...                                                   ...
# 916267                                                0.0
# 916268                                                0.0
# 916269                                                0.0
# 916270                                                0.0
# 916271                                                0.0
#
#         Total fuel consumed in driver-selectable charge increasing operation (lifetime) (l)  \
# 916172                                                0.0
# 916173                                                0.0
# 916174                                                0.0
# 916175                                                0.0
# 916176                                                0.0
# ...                                                   ...
# 916267                                                0.0
# 916268                                                0.0
# 916269                                                0.0
# 916270                                                0.0
# 916271                                                0.0
#
#         Total grid energy into the battery (lifetime) (kWh)  \
# 916172                                                0.0
# 916173                                                0.0
# 916174                                                0.0
# 916175                                                0.0
# 916176                                                0.0
# ...                                                   ...
# 916267                                                0.0
# 916268                                                0.0
# 916269                                                0.0
# 916270                                                0.0
# 916271                                                0.0
#
#         Used in calculation
# 916172                    1
# 916173                    1
# 916174                    1
# 916175                    1
# 916176                    1
# ...                     ...
# 916267                    1
# 916268                    1
# 916269                    0
# 916270                    0
# 916271                    1
#
# [100 rows x 13 columns]

# %%
car_agg.head(20)
# Out:
#            Manufacturer        Fuel Type  Number of vehicles  \
# 0                   KIA           PETROL                1025
# 1                 SKODA           PETROL                2494
# 2         HYUNDAI CZECH           PETROL                1592
# 3                TOYOTA           PETROL                6338
# 4      MERCEDES-BENZ AG           PETROL               29995
# 5                 VOLVO           DIESEL               18674
# 6   AUTOMOBILES CITROEN           PETROL                2457
# 7            FIAT GROUP           DIESEL                6470
# 8            AUDI SPORT           PETROL                 464
# 9           ROLLS ROYCE           PETROL                  20
# 10                VOLVO  DIESEL/ELECTRIC                   1
# 11              RENAULT           PETROL               28846
# 12               BMW AG  PETROL/ELECTRIC                7521
# 13             BMW GMBH           PETROL                1519
# 14              PORSCHE  PETROL/ELECTRIC                1210
# 15                 SEAT           DIESEL                1495
# 16               TOYOTA           DIESEL                   8
# 17                DACIA           DIESEL                 833
# 18           FIAT GROUP           PETROL               15126
# 19           ALFA ROMEO           DIESEL                1751
#
#     OBFCM Fuel consumption (l/100 km)  WLTP Fuel consumption (l/100 km)  \
# 0                                6.39                              5.56
# 1                                7.29                              6.13
# 2                                7.22                              6.26
# 3                                5.60                              4.99
# 4                               10.53                              8.46
# 5                                7.28                              6.23
# 6                                6.49                              5.63
# 7                                5.85                              4.93
# 8                               14.44                             11.54
# 9                               18.79                             15.97
# 10                              10.47                              1.82
# 11                               7.48                              5.72
# 12                               6.73                              1.65
# 13                              14.76                             11.17
# 14                              10.79                              3.03
# 15                               6.57                              5.30
# 16                              10.73                              9.34
# 17                               5.81                              4.89
# 18                               7.01                              5.85
# 19                               7.42                              5.85
#
#     absolute gap Fuel consumption (l/100 km)  \
# 0                                       0.82
# 1                                       1.16
# 2                                       0.95
# 3                                       0.61
# 4                                       2.07
# 5                                       1.05
# 6                                       0.87
# 7                                       0.92
# 8                                       2.91
# 9                                       2.82
# 10                                      8.65
# 11                                      1.76
# 12                                      5.08
# 13                                      3.59
# 14                                      7.76
# 15                                      1.26
# 16                                      1.38
# 17                                      0.92
# 18                                      1.17
# 19                                      1.57
#
#     percentage gap Fuel consumption (%)  OBFCM CO2 emissions (g/km)  \
# 0                                 14.78                      145.50
# 1                                 18.96                      166.07
# 2                                 15.23                      164.36
# 3                                 12.27                      127.52
# 4                                 24.45                      239.83
# 5                                 16.85                      191.48
# 6                                 15.44                      147.95
# 7                                 18.67                      153.96
# 8                                 25.18                      329.00
# 9                                 17.66                      428.10
# 10                               474.00                      275.52
# 11                                30.74                      170.42
# 12                               308.65                      153.29
# 13                                32.15                      336.28
# 14                               256.01                      245.71
# 15                                23.81                      172.79
# 16                                14.82                      282.18
# 17                                18.78                      152.74
# 18                                19.93                      159.72
# 19                                26.81                      195.11
#
#     WLTP CO2 emissions (g/km)  absolute gap CO2 emissions (g/km)  \
# 0                      126.76                              18.74
# 1                      139.60                              26.47
# 2                      142.64                              21.72
# 3                      113.59                              13.93
# 4                      192.71                              47.13
# 5                      163.86                              27.62
# 6                      128.15                              19.79
# 7                      129.74                              24.22
# 8                      262.82                              66.18
# 9                      363.85                              64.25
# 10                      48.00                             227.52
# 11                     130.35                              40.07
# 12                      37.51                             115.78
# 13                     254.47                              81.81
# 14                      69.02                             176.69
# 15                     139.55                              33.23
# 16                     245.75                              36.43
# 17                     128.59                              24.15
# 18                     133.18                              26.55
# 19                     153.86                              41.25
#
#     percentage gap CO2 emissions (%)  \
# 0                              14.78
# 1                              18.96
# 2                              15.23
# 3                              12.27
# 4                              24.45
# 5                              16.85
# 6                              15.44
# 7                              18.67
# 8                              25.18
# 9                              17.66
# 10                            474.00
# 11                             30.74
# 12                            308.65
# 13                             32.15
# 14                            256.01
# 15                             23.81
# 16                             14.82
# 17                             18.78
# 18                             19.93
# 19                             26.81
#
#     OBFCM Fuel consumption weighted (l/100 km)  \
# 0                                         6.33
# 1                                         7.16
# 2                                         7.09
# 3                                         5.67
# 4                                        10.68
# 5                                         7.05
# 6                                         6.35
# 7                                         5.64
# 8                                        14.23
# 9                                        17.63
# 10                                       10.47
# 11                                        7.29
# 12                                        6.95
# 13                                       14.80
# 14                                       10.80
# 15                                        6.47
# 16                                       10.41
# 17                                        5.85
# 18                                        6.80
# 19                                        7.31
#
#     WLTP Fuel consumption weighted (l/100 km)  \
# 0                                        5.60
# 1                                        6.12
# 2                                        6.23
# 3                                        5.05
# 4                                        8.67
# 5                                        6.19
# 6                                        5.64
# 7                                        4.88
# 8                                       11.77
# 9                                       15.97
# 10                                       1.82
# 11                                       5.72
# 12                                       1.63
# 13                                      11.26
# 14                                       3.02
# 15                                       5.29
# 16                                       9.37
# 17                                       4.88
# 18                                       5.89
# 19                                       5.84
#
#     absolute gap Fuel consumption weighted (l/100 km)  \
# 0                                                0.72
# 1                                                1.03
# 2                                                0.86
# 3                                                0.62
# 4                                                2.01
# 5                                                0.86
# 6                                                0.72
# 7                                                0.76
# 8                                                2.46
# 9                                                1.65
# 10                                               8.65
# 11                                               1.57
# 12                                               5.32
# 13                                               3.55
# 14                                               7.78
# 15                                               1.18
# 16                                               1.04
# 17                                               0.98
# 18                                               0.92
# 19                                               1.46
#
#     percentage gap Fuel consumption weighted (%)  \
# 0                                          12.93
# 1                                          16.90
# 2                                          13.83
# 3                                          12.30
# 4                                          23.12
# 5                                          13.82
# 6                                          12.76
# 7                                          15.65
# 8                                          20.87
# 9                                          10.36
# 10                                        474.00
# 11                                         27.50
# 12                                        327.54
# 13                                         31.51
# 14                                        257.58
# 15                                         22.28
# 16                                         11.05
# 17                                         20.03
# 18                                         15.57
# 19                                         25.06
#
#     OBFCM CO2 emissions weighted (g/km)  WLTP CO2 emissions weighted (g/km)  \
# 0                                144.17                              127.66
# 1                                163.03                              139.45
# 2                                161.59                              141.95
# 3                                129.15                              115.00
# 4                                243.30                              197.61
# 5                                185.51                              162.98
# 6                                144.75                              128.37
# 7                                148.48                              128.39
# 8                                324.21                              268.23
# 9                                401.54                              363.84
# 10                               275.52                               48.00
# 11                               166.16                              130.32
# 12                               158.33                               37.03
# 13                               337.22                              256.42
# 14                               246.06                               68.81
# 15                               170.11                              139.12
# 16                               273.78                              246.55
# 17                               153.98                              128.28
# 18                               154.97                              134.09
# 19                               192.29                              153.76
#
#     absolute gap CO2 emissions weighted (g/km)  \
# 0                                        16.51
# 1                                        23.57
# 2                                        19.63
# 3                                        14.14
# 4                                        45.68
# 5                                        22.53
# 6                                        16.38
# 7                                        20.09
# 8                                        55.98
# 9                                        37.69
# 10                                      227.52
# 11                                       35.84
# 12                                      121.29
# 13                                       80.80
# 14                                      177.25
# 15                                       30.99
# 16                                       27.23
# 17                                       25.69
# 18                                       20.88
# 19                                       38.53
#
#     percentage gap CO2 emissions weighted (%)
# 0                                       12.93
# 1                                       16.90
# 2                                       13.83
# 3                                       12.30
# 4                                       23.12
# 5                                       13.82
# 6                                       12.76
# 7                                       15.65
# 8                                       20.87
# 9                                       10.36
# 10                                     474.00
# 11                                      27.50
# 12                                     327.54
# 13                                      31.51
# 14                                     257.58
# 15                                      22.28
# 16                                      11.05
# 17                                      20.03
# 18                                      15.57
# 19                                      25.06

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 916272 entries, 0 to 916271
# Data columns (total 13 columns):
#  #   Column                                                                                      Non-Null Count   Dtype
# ---  ------                                                                                      --------------   -----
#  0   OBFCM data source                                                                           916272 non-null  object
#  1   ID                                                                                          916272 non-null  int64
#  2   OBFCM ReportingPeriod                                                                       916272 non-null  int64
#  3   Registration Year                                                                           916272 non-null  int64
#  4   Total fuel consumed (lifetime) (l)                                                          916272 non-null  float64
#  5   Total distance travelled (lifetime) (km)                                                    916272 non-null  float64
#  6   Total distance travelled in charge depleting operation with engine off (lifetime) (km)      444704 non-null  float64
#  7   Total distance travelled in charge depleting operation with engine running (lifetime) (km)  444549 non-null  float64
#  8   Total distance travelled in driver-selectable charge increasing operation (lifetime)  (km)  448022 non-null  float64
#  9   Total fuel consumed in charge depleting operation (lifetime) (l)                            441587 non-null  float64
#  10  Total fuel consumed in driver-selectable charge increasing operation (lifetime) (l)         437898 non-null  float64
#  11  Total grid energy into the battery (lifetime) (kWh)                                         447005 non-null  float64
#  12  Used in calculation                                                                         916272 non-null  int64
# dtypes: float64(8), int64(4), object(1)
# memory usage: 90.9+ MB

# %%
car.describe().round(2).T
# Out:
#                                                        count         mean  \
# ID                                                  916272.0  47412721.14
# OBFCM ReportingPeriod                               916272.0      2021.00
# Registration Year                                   916272.0      2021.00
# Total fuel consumed (lifetime) (l)                  916272.0       500.03
# Total distance travelled (lifetime) (km)            916272.0      7196.20
# Total distance travelled in charge depleting op...  444704.0     49218.04
# Total distance travelled in charge depleting op...  444549.0     47685.60
# Total distance travelled in driver-selectable c...  448022.0   5330228.43
# Total fuel consumed in charge depleting operati...  441587.0      4864.17
# Total fuel consumed in driver-selectable charge...  437898.0    290042.27
# Total grid energy into the battery (lifetime) (...  447005.0       659.67
# Used in calculation                                 916272.0         0.67
#
#                                                             std     min  \
# ID                                                  14267006.73    10.0
# OBFCM ReportingPeriod                                      0.00  2021.0
# Registration Year                                          0.00  2021.0
# Total fuel consumed (lifetime) (l)                       673.45     0.0
# Total distance travelled (lifetime) (km)               20758.64     0.0
# Total distance travelled in charge depleting op...   3189666.63     0.0
# Total distance travelled in charge depleting op...   3188122.77     0.0
# Total distance travelled in driver-selectable c...  47442242.87     0.0
# Total fuel consumed in charge depleting operati...    319953.74     0.0
# Total fuel consumed in driver-selectable charge...   3502749.57     0.0
# Total grid energy into the battery (lifetime) (...    321198.90     0.0
# Used in calculation                                        0.47     0.0
#
#                                                             25%          50%  \
# ID                                                  46733343.50  51613296.00
# OBFCM ReportingPeriod                                   2021.00      2021.00
# Registration Year                                       2021.00      2021.00
# Total fuel consumed (lifetime) (l)                         5.16       268.33
# Total distance travelled (lifetime) (km)                  29.00      4043.50
# Total distance travelled in charge depleting op...         0.00         0.00
# Total distance travelled in charge depleting op...         0.00         0.00
# Total distance travelled in driver-selectable c...         0.00         0.00
# Total fuel consumed in charge depleting operati...         0.00         0.00
# Total fuel consumed in driver-selectable charge...         0.00         0.00
# Total grid energy into the battery (lifetime) (...         0.00         0.00
# Used in calculation                                        0.00         1.00
#
#                                                             75%           max
# ID                                                  54876879.50  6.129939e+07
# OBFCM ReportingPeriod                                   2021.00  2.021000e+03
# Registration Year                                       2021.00  2.021000e+03
# Total fuel consumed (lifetime) (l)                       713.74  2.891299e+04
# Total distance travelled (lifetime) (km)               10333.00  1.711298e+07
# Total distance travelled in charge depleting op...       408.82  2.147484e+08
# Total distance travelled in charge depleting op...        79.90  2.147484e+08
# Total distance travelled in driver-selectable c...         0.00  4.294967e+08
# Total fuel consumed in charge depleting operati...         8.11  2.147484e+07
# Total fuel consumed in driver-selectable charge...         0.00  4.294967e+07
# Total grid energy into the battery (lifetime) (...        54.00  2.147485e+08
# Used in calculation                                        1.00  1.000000e+00

# %%
car.isnull().sum()
# Out:
# OBFCM data source                                                                                  0
# ID                                                                                                 0
# OBFCM ReportingPeriod                                                                              0
# Registration Year                                                                                  0
# Total fuel consumed (lifetime) (l)                                                                 0
# Total distance travelled (lifetime) (km)                                                           0
# Total distance travelled in charge depleting operation with engine off (lifetime) (km)        471568
# Total distance travelled in charge depleting operation with engine running (lifetime) (km)    471723
# Total distance travelled in driver-selectable charge increasing operation (lifetime)  (km)    468250
# Total fuel consumed in charge depleting operation (lifetime) (l)                              474685
# Total fuel consumed in driver-selectable charge increasing operation (lifetime) (l)           478374
# Total grid energy into the battery (lifetime) (kWh)                                           469267
# Used in calculation                                                                                0
# dtype: int64

# %% [markdown]
# # Fixing missing values

# %%
# Calculate the mean of each column
#Total distance travelled in charge depleting operation with engine off (lifetime) (km)
column1_mean = car['Total distance travelled in charge depleting operation with engine off (lifetime) (km)'].mean()

# Fill missing values with the mean
car['Total distance travelled in charge depleting operation with engine off (lifetime) (km)'] = car['Total distance travelled in charge depleting operation with engine off (lifetime) (km)'].fillna(column1_mean)


#Total distance travelled in charge depleting operation with engine off (lifetime) (km)
column2_mean = car['Total distance travelled in charge depleting operation with engine running (lifetime) (km)'].mean()

# Fill missing values with the mean
car['Total distance travelled in charge depleting operation with engine running (lifetime) (km)'] = car['Total distance travelled in charge depleting operation with engine running (lifetime) (km)'].fillna(column2_mean)


#Total distance travelled in driver-selectable charge increasing operation (lifetime)  (km)
column3_mean = car['Total distance travelled in driver-selectable charge increasing operation (lifetime)  (km)'].mean()

# Fill missing values with the mean
car['Total distance travelled in driver-selectable charge increasing operation (lifetime)  (km)'] = car['Total distance travelled in driver-selectable charge increasing operation (lifetime)  (km)'].fillna(column3_mean)


#Total fuel consumed in charge depleting operation (lifetime) (l)
column4_mean = car['Total fuel consumed in charge depleting operation (lifetime) (l)'].mean()

# Fill missing values with the mean
car['Total fuel consumed in charge depleting operation (lifetime) (l)'] = car['Total fuel consumed in charge depleting operation (lifetime) (l)'].fillna(column4_mean)


#Total fuel consumed in driver-selectable charge increasing operation (lifetime) (l)
column5_mean = car['Total fuel consumed in driver-selectable charge increasing operation (lifetime) (l)'].mean()

# Fill missing values with the mean
car['Total fuel consumed in driver-selectable charge increasing operation (lifetime) (l)'] = car['Total fuel consumed in driver-selectable charge increasing operation (lifetime) (l)'].fillna(column5_mean)

#Total grid energy into the battery (lifetime) (kWh)
column6_mean = car['Total grid energy into the battery (lifetime) (kWh)'].mean()

# Fill missing values with the mean
car['Total grid energy into the battery (lifetime) (kWh)'] = car['Total grid energy into the battery (lifetime) (kWh)'].fillna(column6_mean)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 916272 entries, 0 to 916271
# Data columns (total 13 columns):
#  #   Column                                                                                      Non-Null Count   Dtype
# ---  ------                                                                                      --------------   -----
#  0   OBFCM data source                                                                           916272 non-null  object
#  1   ID                                                                                          916272 non-null  int64
#  2   OBFCM ReportingPeriod                                                                       916272 non-null  int64
#  3   Registration Year                                                                           916272 non-null  int64
#  4   Total fuel consumed (lifetime) (l)                                                          916272 non-null  float64
#  5   Total distance travelled (lifetime) (km)                                                    916272 non-null  float64
#  6   Total distance travelled in charge depleting operation with engine off (lifetime) (km)      916272 non-null  float64
#  7   Total distance travelled in charge depleting operation with engine running (lifetime) (km)  916272 non-null  float64
#  8   Total distance travelled in driver-selectable charge increasing operation (lifetime)  (km)  916272 non-null  float64
#  9   Total fuel consumed in charge depleting operation (lifetime) (l)                            916272 non-null  float64
#  10  Total fuel consumed in driver-selectable charge increasing operation (lifetime) (l)         916272 non-null  float64
#  11  Total grid energy into the battery (lifetime) (kWh)                                         916272 non-null  float64
#  12  Used in calculation                                                                         916272 non-null  int64
# dtypes: float64(8), int64(4), object(1)
# memory usage: 90.9+ MB

# %%
## loading Car aggregated Data set
car_agg=pd.read_csv("2021_Cars_Aggregated.csv")

# %%
car_agg.head()
# Out:
#        Manufacturer Fuel Type  Number of vehicles  \
# 0               KIA    PETROL                1025
# 1             SKODA    PETROL                2494
# 2     HYUNDAI CZECH    PETROL                1592
# 3            TOYOTA    PETROL                6338
# 4  MERCEDES-BENZ AG    PETROL               29995
#
#    OBFCM Fuel consumption (l/100 km)  WLTP Fuel consumption (l/100 km)  \
# 0                               6.39                              5.56
# 1                               7.29                              6.13
# 2                               7.22                              6.26
# 3                               5.60                              4.99
# 4                              10.53                              8.46
#
#    absolute gap Fuel consumption (l/100 km)  \
# 0                                      0.82
# 1                                      1.16
# 2                                      0.95
# 3                                      0.61
# 4                                      2.07
#
#    percentage gap Fuel consumption (%)  OBFCM CO2 emissions (g/km)  \
# 0                                14.78                      145.50
# 1                                18.96                      166.07
# 2                                15.23                      164.36
# 3                                12.27                      127.52
# 4                                24.45                      239.83
#
#    WLTP CO2 emissions (g/km)  absolute gap CO2 emissions (g/km)  \
# 0                     126.76                              18.74
# 1                     139.60                              26.47
# 2                     142.64                              21.72
# 3                     113.59                              13.93
# 4                     192.71                              47.13
#
#    percentage gap CO2 emissions (%)  \
# 0                             14.78
# 1                             18.96
# 2                             15.23
# 3                             12.27
# 4                             24.45
#
#    OBFCM Fuel consumption weighted (l/100 km)  \
# 0                                        6.33
# 1                                        7.16
# 2                                        7.09
# 3                                        5.67
# 4                                       10.68
#
#    WLTP Fuel consumption weighted (l/100 km)  \
# 0                                       5.60
# 1                                       6.12
# 2                                       6.23
# 3                                       5.05
# 4                                       8.67
#
#    absolute gap Fuel consumption weighted (l/100 km)  \
# 0                                               0.72
# 1                                               1.03
# 2                                               0.86
# 3                                               0.62
# 4                                               2.01
#
#    percentage gap Fuel consumption weighted (%)  \
# 0                                         12.93
# 1                                         16.90
# 2                                         13.83
# 3                                         12.30
# 4                                         23.12
#
#    OBFCM CO2 emissions weighted (g/km)  WLTP CO2 emissions weighted (g/km)  \
# 0                               144.17                              127.66
# 1                               163.03                              139.45
# 2                               161.59                              141.95
# 3                               129.15                              115.00
# 4                               243.30                              197.61
#
#    absolute gap CO2 emissions weighted (g/km)  \
# 0                                       16.51
# 1                                       23.57
# 2                                       19.63
# 3                                       14.14
# 4                                       45.68
#
#    percentage gap CO2 emissions weighted (%)
# 0                                      12.93
# 1                                      16.90
# 2                                      13.83
# 3                                      12.30
# 4                                      23.12

# %% [markdown]
# # EDA

# %%
car_agg["Manufacturer"].value_counts()
# Out:
# Manufacturer
# MERCEDES-BENZ AG                 4
# VOLVO                            4
# KIA                              3
# SEAT                             3
# AUDI AG                          3
# VOLKSWAGEN                       3
# OPEL AUTOMOBILE                  3
# HYUNDAI                          3
# JAGUAR LAND ROVER LIMITED        3
# PSA                              3
# CHRYSLER                         3
# SKODA                            3
# KIA SLOVAKIA                     3
# FORD WERKE GMBH                  3
# AUTOMOBILES PEUGEOT              3
# TOYOTA                           3
# BMW AG                           3
# RENAULT                          3
# HYUNDAI CZECH                    3
# FIAT GROUP                       3
# AUDI HUNGARIA                    2
# AUTOMOBILES CITROEN              2
# FERRARI                          2
# ALFA ROMEO                       2
# BENTLEY                          2
# DACIA                            2
# SUZUKI MOTOR CORPORATION         2
# PORSCHE                          2
# MAZDA                            2
# MITSUBISHI MOTORS CORPORATION    1
# MAGYAR SUZUKI                    1
# CNG TECHNIK                      1
# HYUNDAI ASSAN                    1
# SAIC MOTOR CORPORATION           1
# SUBARU                           1
# FORD MOTOR COMPANY               1
# MITSUBISHI MOTORS THAILAND       1
# AUDI SPORT                       1
# ROLLS ROYCE                      1
# BMW GMBH                         1
# TOYOTA MOTOR CORPORATION         1
# NISSAN AUTOMOTIVE EUROPE         1
# MERCEDES AMG                     1
# Name: count, dtype: int64

# %%
car_agg["Fuel Type"].value_counts()
# Out:
# Fuel Type
# PETROL             41
# PETROL/ELECTRIC    26
# DIESEL             25
# DIESEL/ELECTRIC     2
# Name: count, dtype: int64

# %%
labels = ['PETROL', 'PETROL/ELECTRIC', 'DIESEL', 'DIESEL/ELECTRIC']
sizes = car_agg["Fuel Type"].value_counts()

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Title
plt.title('Fuel Type Distribution of Cars')

# Show plot
plt.show()

# %%
car_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 19 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Manufacturer                                       94 non-null     object
#  1   Fuel Type                                          94 non-null     object
#  2   Number of vehicles                                 94 non-null     int64
#  3   OBFCM Fuel consumption (l/100 km)                  94 non-null     float64
#  4   WLTP Fuel consumption (l/100 km)                   94 non-null     float64
#  5   absolute gap Fuel consumption (l/100 km)           94 non-null     float64
#  6   percentage gap Fuel consumption (%)                94 non-null     float64
#  7   OBFCM CO2 emissions (g/km)                         94 non-null     float64
#  8   WLTP CO2 emissions (g/km)                          94 non-null     float64
#  9   absolute gap CO2 emissions (g/km)                  94 non-null     float64
#  10  percentage gap CO2 emissions (%)                   94 non-null     float64
#  11  OBFCM Fuel consumption weighted (l/100 km)         94 non-null     float64
#  12  WLTP Fuel consumption weighted (l/100 km)          94 non-null     float64
#  13  absolute gap Fuel consumption weighted (l/100 km)  94 non-null     float64
#  14  percentage gap Fuel consumption weighted (%)       94 non-null     float64
#  15  OBFCM CO2 emissions weighted (g/km)                94 non-null     float64
#  16  WLTP CO2 emissions weighted (g/km)                 94 non-null     float64
#  17  absolute gap CO2 emissions weighted (g/km)         94 non-null     float64
#  18  percentage gap CO2 emissions weighted (%)          94 non-null     float64
# dtypes: float64(16), int64(1), object(2)
# memory usage: 14.1+ KB

# %%
car_agg.describe().round(2).T
# Out:
#                                                    count     mean       std  \
# Number of vehicles                                  94.0  6565.89  12322.67
# OBFCM Fuel consumption (l/100 km)                   94.0     7.84      3.28
# WLTP Fuel consumption (l/100 km)                    94.0     5.36      3.05
# absolute gap Fuel consumption (l/100 km)            94.0     2.48      2.17
# percentage gap Fuel consumption (%)                 94.0    94.97    122.27
# OBFCM CO2 emissions (g/km)                          94.0   185.65     74.12
# WLTP CO2 emissions (g/km)                           94.0   127.63     70.77
# absolute gap CO2 emissions (g/km)                   94.0    58.01     50.13
# percentage gap CO2 emissions (%)                    94.0    94.97    122.27
# OBFCM Fuel consumption weighted (l/100 km)          94.0     7.69      3.23
# WLTP Fuel consumption weighted (l/100 km)           94.0     5.37      3.07
# absolute gap Fuel consumption weighted (l/100 km)   94.0     2.32      2.21
# percentage gap Fuel consumption weighted (%)        94.0    91.33    123.32
# OBFCM CO2 emissions weighted (g/km)                 94.0   182.11     72.83
# WLTP CO2 emissions weighted (g/km)                  94.0   127.75     71.15
# absolute gap CO2 emissions weighted (g/km)          94.0    54.36     51.09
# percentage gap CO2 emissions weighted (%)           94.0    91.33    123.32
#
#                                                      min     25%      50%  \
# Number of vehicles                                  1.00  106.50  1671.50
# OBFCM Fuel consumption (l/100 km)                   3.87    5.84     6.85
# WLTP Fuel consumption (l/100 km)                    0.97    2.60     5.62
# absolute gap Fuel consumption (l/100 km)            0.04    1.00     1.50
# percentage gap Fuel consumption (%)                 0.78   16.99    21.92
# OBFCM CO2 emissions (g/km)                         88.13  142.22   163.36
# WLTP CO2 emissions (g/km)                          22.00   59.12   132.30
# absolute gap CO2 emissions (g/km)                   1.02   25.11    36.33
# percentage gap CO2 emissions (%)                    0.78   16.99    21.92
# OBFCM Fuel consumption weighted (l/100 km)          2.82    5.90     6.78
# WLTP Fuel consumption weighted (l/100 km)           0.97    2.53     5.60
# absolute gap Fuel consumption weighted (l/100 km)   0.06    0.90     1.38
# percentage gap Fuel consumption weighted (%)        1.01   15.32    20.56
# OBFCM CO2 emissions weighted (g/km)                64.21  143.66   160.61
# WLTP CO2 emissions weighted (g/km)                 22.00   57.68   132.55
# absolute gap CO2 emissions weighted (g/km)          1.32   21.85    31.86
# percentage gap CO2 emissions weighted (%)           1.01   15.32    20.56
#
#                                                        75%       max
# Number of vehicles                                 6771.50  84828.00
# OBFCM Fuel consumption (l/100 km)                     8.36     20.06
# WLTP Fuel consumption (l/100 km)                      6.61     15.97
# absolute gap Fuel consumption (l/100 km)              3.85     13.18
# percentage gap Fuel consumption (%)                 192.01    474.00
# OBFCM CO2 emissions (g/km)                          193.98    457.03
# WLTP CO2 emissions (g/km)                           157.82    363.85
# absolute gap CO2 emissions (g/km)                    87.67    300.25
# percentage gap CO2 emissions (%)                    192.01    474.00
# OBFCM Fuel consumption weighted (l/100 km)            8.20     19.59
# WLTP Fuel consumption weighted (l/100 km)             6.60     15.97
# absolute gap Fuel consumption weighted (l/100 km)     3.73     12.72
# percentage gap Fuel consumption weighted (%)        181.56    474.00
# OBFCM CO2 emissions weighted (g/km)                 191.17    446.34
# WLTP CO2 emissions weighted (g/km)                  156.72    363.84
# absolute gap CO2 emissions weighted (g/km)           84.91    289.69
# percentage gap CO2 emissions weighted (%)           181.56    474.00
